# %% [markdown]
# # Task 1

# %% [markdown]
# ## Web Scraping and Analysis

# %% [markdown]
# This is the project inspired by my interest in Southwest Airlines - where I was internning during the summer as a BI Engineer. This Jupyter notebook shows the code web scraping and analysis. The package used for the web scraping is called `BeautifulSoup` to collect the data from the web. Once collected, the data is saved into a local `.csv` file, and then I start the analysis.

# %% [markdown]
# ### Scraping data from Skytrax

# %% [markdown]
# The data expected to be used for this task can be gotten from the website provided https://www.airlinequality.com. However, for the purpose of this task, we only interested in the reviews related to British Airways and Airline.
#
# A navigation to this link: https://www.airlinequality.com/airline-reviews/british-airways will display this data. We can use Python and the `BeautifulSoup` library to collect all the reviews.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import csv
from wordcloud import WordCloud 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import pandas as pd

# %%
base_url = 'https://www.airlinequality.com/airline-reviews/southwest-airlines'
pages = 10
page_size = 100 

reviews = []
aircraft = []
seat_type = []
route = []
recommended = []
df = pd.DataFrame()

# for i in range(1, pages + 1):
for i in range(1, pages + 1):
    
    rating = []
    category = []

    print(f"Scraping page {i}")

    # Create URL to collect links from paginated data
    url = f"{base_url}/page/{i}/?sortby=post_date%3ADesc&pagesize={page_size}"

    # Collect HTML data from this page
    response = requests.get(url)

    # Parse content
    content = response.content
    parsed_content = BeautifulSoup(content, 'html.parser')
    for para in parsed_content.find_all("div", {"class": "text_content"}):
        reviews.append(para.get_text())
        
    for para2 in parsed_content.find_all("div", {"class" : "review-stats"}):
        for para3 in para2.find_all('td',{'class' : 'review-value'}):
            rating.append(para3.get_text())
        recomend = rating[-1]
        rating = rating[:-1]
        
        for para4 in para2.find_all('td',{'class' : 'review-rating-stars stars'}):
            para5 = len(para4.find_all('span', {'class' : 'star fill'}))
            rating.append(para5)
        rating.append(recomend)
        #print(rating)
        
        for para6 in para2.find_all('td',{'class' : 'review-rating-header'}):
            category.append(para6.get_text())
            
        
        # Create the records from both list, using zip and dict calls.

        # Build the dataframe from the dictionary.
        data_dict = pd.DataFrame([rating], columns=category)
        df = pd.concat([df, data_dict], ignore_index=True).reset_index(drop=True)
        #print(df)
        rating = []
        category = []
        
    print(f"   ---> {len(reviews)} total reviews")

df["reviews"] = reviews
warnings.filterwarnings('ignore')
# Out:
# Scraping page 1
#    ---> 100 total reviews
# Scraping page 2
#    ---> 200 total reviews
# Scraping page 3
#    ---> 300 total reviews
# Scraping page 4
#    ---> 400 total reviews
# Scraping page 5
#    ---> 500 total reviews
# Scraping page 6
#    ---> 600 total reviews
# Scraping page 7
#    ---> 700 total reviews
# Scraping page 8
#    ---> 800 total reviews
# Scraping page 9
#    ---> 900 total reviews
# Scraping page 10
#    ---> 1000 total reviews

# %%
df.sample(5)
# Out:
#     Aircraft Type Of Traveller        Seat Type                       Route  \
# 604      NaN    Couple Leisure    Economy Class          Phoenix to Chicago
# 347      NaN          Business    Economy Class        Raleigh to Baltimore
# 652      NaN      Solo Leisure    Economy Class  San Francisco to Las Vegas
# 942      NaN      Solo Leisure  Premium Economy  Atlanta to Norfolk Virgina
# 636      NaN    Family Leisure    Economy Class       Las Vegas to Portland
#
#      Date Flown  Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 604   June 2021           3.0                  3.0               1.0
# 347   June 2022           1.0                  2.0               1.0
# 652  March 2021           3.0                  4.0               3.0
# 942   June 2019           5.0                  5.0               5.0
# 636   June 2021           2.0                  1.0               1.0
#
#      Inflight Entertainment  Ground Service  Wifi & Connectivity  \
# 604                     2.0             3.0                  2.0
# 347                     NaN             1.0                  1.0
# 652                     NaN             4.0                  NaN
# 942                     NaN             5.0                  5.0
# 636                     1.0             1.0                  1.0
#
#      Value For Money Recommended  \
# 604              3.0          no
# 347              1.0          no
# 652              3.0         yes
# 942              5.0         yes
# 636              1.0          no
#
#                                                reviews
# 604  Not Verified |  I’m over Southwest! Flight can...
# 347  ✅ Trip Verified |  A simple 1 hour flight. Not...
# 652  Not Verified |  SFO to LAS, quick and easy fli...
# 942  ✅ Trip Verified | I flew from Atlanta to Norfo...
# 636  Not Verified |  Absolutely terrible customer s...

# %%
df.to_csv("SWA_reviews.csv", index=False)

# %%
df.shape
# Out:
# (1000, 14)

# %%
remove_text = ['✅ Trip Verified', 'Not Verified |']

for i in range(len(df['reviews'])):
    for j in remove_text:
        if j in df['reviews'][i]:
            df['reviews'] = df['reviews'].str.replace(j,'')

# %%
df.sample(5)
# Out:
#            Aircraft Type Of Traveller      Seat Type  \
# 441  Boeing 737-800      Solo Leisure  Economy Class
# 808  Boeing 737-800      Solo Leisure  Economy Class
# 220             NaN      Solo Leisure  Economy Class
# 971             NaN      Solo Leisure  Economy Class
# 739             NaN    Family Leisure  Economy Class
#
#                                        Route     Date Flown  Seat Comfort  \
# 441  Columbus to Colorado Springs via Denver  February 2022           1.0
# 808                   Las Vegas to Milwaukee   January 2020           3.0
# 220         Ontario to Charleston via Denver  December 2022           3.0
# 971                Indianapolis to San Diego   October 2018           1.0
# 739            Raleigh/Durham to Albuquerque     March 2020           NaN
#
#      Cabin Staff Service  Food & Beverages  Inflight Entertainment  \
# 441                  2.0               2.0                     NaN
# 808                  4.0               4.0                     1.0
# 220                  5.0               NaN                     NaN
# 971                  1.0               1.0                     1.0
# 739                  NaN               NaN                     NaN
#
#      Ground Service  Wifi & Connectivity  Value For Money Recommended  \
# 441             1.0                  NaN              1.0          no
# 808             3.0                  1.0              3.0         yes
# 220             1.0                  NaN              1.0          no
# 971             1.0                  1.0              1.0          no
# 739             NaN                  NaN              1.0          no
#
#                                                reviews
# 441   | Very disappointed with Southwest. Will not ...
# 808   |  Las Vegas to Milwaukee. First time trying ...
# 220   |  Been on hold for 5 hours to get an update ...
# 971    Indianapolis to San Diego with Southwest Air...
# 739   |  I scheduled a spring break trip for my tee...

# %%
df.to_csv("SWA_reviews_cleaned_unwanted_text.csv", index=False)

# %% [markdown]
# # Data Analysis

# %%
review_word = []

for i in df['reviews'] :
    a = i.split(' ')
    for x in a:
        review_word.append(x)
        
unique_string = (" ").join(review_word)

wc = WordCloud(width = 1000, height = 450, background_color = 'white').generate(unique_string)
plt.figure(figsize=(15,8))
plt.imshow(wc)
plt.axis("off")
plt.show()

# %% [markdown]
# From the wordcloud above, we can see the key topics in customer review are flight, Airport, luggage, time, and customer service. This shows that people are actively talking about their experience on the plane and their experience with the staff.

# %% [markdown]
# **Customer Satisfaction (CS)**

# %%
cs = df.groupby('Recommended')['reviews'].count().reset_index()
plt.pie(cs['reviews'], labels = cs['Recommended'], autopct='%.2f%%',colors = sns.color_palette('pastel'),
          wedgeprops={"edgecolor":"k"},)
plt.legend()
plt.show()

# %% [markdown]
# From the pie chart above, we know that 75% of passengers are dissatisfied with British Airways services. Now, let's breakdown the data to discover what makes passengers dissatisfied :

# %% [markdown]
# **View rating of BA service by passengers that are dissatisfied with British Airways**

# %%
df_cs = df[df['Recommended'] == 'no']
df_cs.describe()
# Out:
#        Seat Comfort  Cabin Staff Service  Food & Beverages  \
# count    660.000000           656.000000        455.000000
# mean       1.768182             2.076220          1.663736
# std        1.012465             1.325147          1.003904
# min        1.000000             1.000000          1.000000
# 25%        1.000000             1.000000          1.000000
# 50%        1.000000             1.000000          1.000000
# 75%        2.000000             3.000000          2.000000
# max        5.000000             5.000000          5.000000
#
#        Inflight Entertainment  Ground Service  Wifi & Connectivity  \
# count              377.000000      691.000000           408.000000
# mean                 1.652520        1.503618             1.622549
# std                  1.093355        0.997636             1.074466
# min                  1.000000        1.000000             1.000000
# 25%                  1.000000        1.000000             1.000000
# 50%                  1.000000        1.000000             1.000000
# 75%                  2.000000        2.000000             2.000000
# max                  5.000000        5.000000             5.000000
#
#        Value For Money
# count       749.000000
# mean          1.479306
# std           0.832920
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max           5.000000

# %% [markdown]
# **Food Analysis on airways**

# %%
data = df_cs[df_cs['reviews'].str.contains('food | drink')]
data['reviews'].to_csv('food_review.csv')

# %%
review_word = []

for i in data['reviews'] :
    a = i.split(' ')
    for x in a:
        review_word.append(x)
        
unique_string = (" ").join(review_word)

wc = WordCloud(width = 1000, height = 450, background_color = 'white').generate(unique_string)
plt.figure(figsize=(15,8))
plt.imshow(wc)
plt.axis("off")
plt.show()

# %% [markdown]
# **Value for money analysis**

# %%
data = df_cs[df_cs['reviews'].str.contains('money | refund & value')]
data['reviews'].to_csv('value_for_money.csv')

# %%
review_word = []

for i in data['reviews'] :
    a = i.split(' ')
    for x in a:
        review_word.append(x)
        
unique_string = (" ").join(review_word)

wc = WordCloud(width = 1000, height = 450, background_color = 'white').generate(unique_string)
plt.figure(figsize=(15,8))
plt.imshow(wc)
plt.axis("off")
plt.show()
